# %%
from bs4 import BeautifulSoup
import requests

# %%
source = "DEL"
destination = "BOM"
travel_date = "28/03/2021"
journey_type = "O"

no_adults = str(1)
no_children = str(0)
no_infants = str(0)

passenger_type = f"A-{no_adults}_C-{no_children}_I-{no_infants}"
itinerary_field = f"{source}-{destination}-{travel_date}"
cabin_class = "E"
is_international = "false"

country_code = "IN"
lang = "eng"

# %%
mmt_url = f"https://www.makemytrip.com/flight/search?itinerary={itinerary_field}&tripType={journey_type}&paxType={passenger_type}&intl={is_international}&cabinClass={cabin_class}&ccde={country_code}&lang={lang}"

# %%
print (mmt_url)
# Out:
# https://www.makemytrip.com/flight/search?itinerary=DEL-BOM-28/03/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=E&ccde=IN&lang=eng

# %%
response_object = requests.get(mmt_url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-186f341d3d88> in <module>
# ----> 1 response_object = requests.get(mmt_url)
#
# ~/anaconda3/envs/internWork01/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/anaconda3/envs/internWork01/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
requests.get("https://www.google.co.in")
# Out:
# <Response [200]>

# %%
import selenium.webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = selenium.webdriver.Chrome('/home/jkhan01/Desktop/chromedriver_linux64/chromedriver')
driver.get(mmt_url)
element_xpath = '//*[@id="left-side--wrapper"]/div[2]' 


element = WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.XPATH, element_xpath)))


print ("Scrolling document upto bottom ...")
for j in range(1, 100):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")


body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")
# Out:
# Scrolling document upto bottom ...

# %%
script_data = BeautifulSoup(body,'lxml')

# %%
# !pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.5 MB 2.3 MB/s eta 0:00:01     |█████████████████████████████▉  | 5.1 MB 2.3 MB/s eta 0:00:01
# ...

# %%
script_data.find_all("div",attrs={'class':'boldFont blackText airlineName'})
# Out:
# []

# %%
pprint.pprint(script_data.text)
# Out:
# (' Flights  Hotels  Villas & Apts  Holidays +Cruise Trains  Buses  Visa  Cabs  '
#  'Charter Flights NEW More  Activities & Tours Trip Ideas Giftcards My Biz '
#  'International Flights International Hotels Deals Blog Login or  Create '
#  'Account  TRIP TYPE One Way FROM  TO  DEPART  RETURN PASSENGERS & '
#  'CLASSSEARCHPopular FiltersNon Stop\xa0(35)₹ 4,662IndiGo\xa0(29)₹ '
#  '4,662Morning Departures\xa0(24)₹ 4,190Late Departures\xa0(14)₹ '
#  '4,165Vistara\xa0(10)₹ 4,664Air India\xa0(9)₹ 4,663Spicejet\xa0(8)₹ 4,165Go '
#  'Air\xa0(7)₹ 4,664AirAsia\xa0(3)₹ 4,664+ 5 moreOne Way Price₹4,165 '
#  '₹7,400Stops From New DelhiNon Stop\xa0(35)₹ 4,6621 Stop\xa0(31)₹ '
#  '4,165Departure From New DelhiBefore 6 AM₹ 4,1906 AM - 12 PM₹ 4,19012 PM - 6 '
#  'PM₹ 4,190After 6 PM₹ 4,165Arrival at MumbaiBefore 6 AM₹ 5,6096 AM - 12 PM₹ '
#  '4,16512 PM - 6 PM₹ 4,190After 6 PM₹ 4,662AirlinesAir India\xa0(9)₹ '
#  '4,663AirAsia\xa0(3)₹ 4,664Go Air\xa0(7)₹ 4,664IndiGo\xa0(29)₹ '
# ...

# %%
import pprint
